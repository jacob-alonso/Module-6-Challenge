# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy
# Out:
# Collecting citipy
#   Downloading citipy-0.0.6.tar.gz (675 kB)
#      ---------------------------------------- 0.0/675.6 kB ? eta -:--:--
#      - ----------------------------------- 20.5/675.6 kB 640.0 kB/s eta 0:00:02
#      ------ ------------------------------- 122.9/675.6 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 675.6/675.6 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting kdtree>=0.12 (from citipy)
#   Downloading kdtree-0.16-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Created wheel for citipy: filename=citipy-0.0.6-py3-none-any.whl size=675975 sha256=4879c76f06befc76ac27c56cec0e706ec9f4c26f7851aa25ded90cd1068df6f4
#   Stored in directory: c:\users\jacob\appdata\local\pip\cache\wheels\4b\b5\88\49107ff846ec6967b34c17d369176c591fc90ed93b706755ad
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.6 kdtree-0.16

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 598

# %%
cities
# Out:
# ['whitehorse',
#  'puerto natales',
#  'olonkinbyen',
#  'oromocto',
#  'enewetak',
#  'fort mcmurray',
#  'grytviken',
#  'adamstown',
#  'albany',
#  'sur',
#  'muricay',
#  'kodiak',
#  'mount gambier',
#  'zapolyarnyy',
#  'cobija',
#  'edinburgh of the seven seas',
#  'santa marta',
#  'yellowknife',
#  'waitangi',
#  'saint-francois',
#  'dunedin',
#  'hithadhoo',
#  'kingston',
#  'belmonte',
#  'abrud',
#  'kaihua',
#  'karangampel',
#  'ushuaia',
#  'puerto baquerizo moreno',
#  'gonabad',
#  'ribeira grande',
#  'alesund',
#  'taiohae',
#  'juneau',
#  'palikir - national government center',
#  'nybro',
#  'nabire',
#  'jamestown',
#  'sept-iles',
#  'turpan',
#  'warrnambool',
#  'poronaysk',
#  'mount pearl',
#  'badger',
#  'iskateley',
#  'utrik',
#  'port mathurin',
#  'hamilton',
#  'tiksi',
#  'qaqortoq',
#  'ubinskoye',
#  'port-aux-francais',
#  'west island',
#  'codrington',
#  'college',
#  'port lincoln',
#  'agogo',
#  'thompson',
#  'wailua homesteads',
#  'hermanus',
#  'aykhal',
#  'kapuskasing',
#  'ciudad melchor muzquiz',
#  'blackmans bay',
#  'helena valley southeast',
#  'fortuna',
#  'medina',
#  'ola',
#  'gaspe',
#  'udachny',
#  'patong',
#  'stanley',
#  'papatowai',
#  'talnakh',
#  'okha',
#  'rio grande',
#  'sorong',
#  'nyurba',
#  'antsiranana',
#  'santo antonio',
#  'weno',
#  'luderitz',
#  'orsa',
#  'avarua',
#  'iqaluit',
#  'pacific grove',
#  'torre de moncorvo',
#  'amal',
#  'anna regina',
#  'brisas de zicatela',
#  'port glaud',
#  'muisne',
#  'khorugh',
#  'nandurbar',
#  'hadibu',
#  'kavaratti',
#  'bethel',
#  'kailua-kona',
#  'carahue',
#  'dudinka',
#  'christchurch',
#  'hasaki',
#  'ugoofaaru',
#  'klyuchi',
#  'margaret river',
#  'saipan',
#  'recani',
#  'mukah',
#  'katabu',
#  'saint-georges',
#  'polyarnyy',
#  'sao felix do xingu',
#  "nar'yan-mar",
#  'uturoa',
#  'longyearbyen',
#  'fale old settlement',
#  'cuatro cienegas de carranza',
#  'jaisinghnagar',
#  'afaahiti',
#  'ikom',
#  'nishinoomote',
#  'san carlos de bariloche',
#  'meadow lake',
#  'den burg',
#  'mogadishu',
#  'bredasdorp',
#  'kudymkar',
#  'aoulef',
#  'puerto ayora',
#  'ust-nera',
#  'akureyri',
#  'hawaiian paradise park',
#  'richlands',
#  'greenville',
#  'tadpatri',
#  'baiyin',
#  'invercargill',
#  'quelimane',
#  'wrzesnia',
#  'vila franca do campo',
#  'mermoz boabab',
#  'chonchi',
#  'ilulissat',
#  'port elizabeth',
#  'tonota',
#  'xai-xai',
#  'hobyo',
#  'abepura',
#  'wellington',
#  'bardai',
#  'hanceville',
#  'vadso',
#  'ancud',
#  'hilo',
#  'kalodzishchy',
#  'vilyuchinsk',
#  'rapid city',
#  'feijo',
#  'touros',
#  'tazovsky',
#  'katsuren-haebaru',
#  'lebu',
#  'vorkuta',
#  'krasnogorskoye',
#  'tura',
#  'san antonio del estrecho',
#  'susuman',
#  'georgetown',
#  'flin flon',
#  'rabaul',
#  'paphos',
#  'buka',
#  'queenstown',
#  'kovdor',
#  'brak',
#  'izucar de matamoros',
#  'thal',
#  'port alfred',
#  'kutztown',
#  'arraial do cabo',
#  'valparaiso',
#  'minbu',
#  'bikenibeu village',
#  'zaigrayevo',
#  'aasiaat',
#  'beledweyne',
#  'neijiang',
#  'sangkhla buri',
#  'anadyr',
#  'pelabuhan klang',
#  'ndago',
#  'cargados carajos',
#  'karratha',
#  'haiku-pauwela',
#  'coquimbo',
#  'castillos',
#  'tanumah',
#  'prince george',
#  'sumbawa besar',
#  'waddan',
#  'tolanaro',
#  'la palma',
#  'urucara',
#  'manatutu',
#  'great falls',
#  'ouesso',
#  'kalix',
#  'kulia village',
#  'nurota',
#  'honcho',
#  'duyun',
#  'upata',
#  'okhotsk',
#  'tamanrasset',
#  'kotli loharan',
#  'weligama',
#  'balikpapan',
#  'midvagur',
#  'kidal',
#  'asadabad',
#  'new norfolk',
#  'camiri',
#  'gap',
#  'labytnangi',
#  'egilsstadir',
#  'islamkot',
#  'slave lake',
#  'east london',
#  'paide',
#  'muniz freire',
#  'kangding',
#  'orikhiv',
#  'qamdo',
#  'galle',
#  'nizao',
#  'omuthiya',
#  'san patricio',
#  "'ohonua",
#  'lorengau',
#  "nuku'alofa",
#  'mbanza kongo',
#  'kalmunai',
#  'tebingtinggi',
#  'santa isabel',
#  'corovode',
#  'finspang',
#  'shani',
#  'ca mau',
#  'isafjordur',
#  'kristiansund',
#  'andergrove',
#  'vingt cinq',
#  "st. john's",
#  'porto novo',
#  'yelovo',
#  'kargasok',
#  'bilibino',
#  'bargara',
#  'mersa matruh',
#  'cromwell',
#  'kaa-khem',
#  'tessaoua',
#  'shimoda',
#  'qandala',
#  'rheinsberg',
#  'sosnogorsk',
#  'tommot',
#  'broken hill',
#  'labrador city',
#  'quellon',
#  'kadisehri',
#  'lompoc',
#  'yarmouth',
#  'dalandzadgad',
#  'agapovka',
#  'flying fish cove',
#  'poli',
#  'esbjerg',
#  'constantia',
#  'le krib',
#  'negara',
#  "'ain benian",
#  'nuuk',
#  'terenozek',
#  'kuqa',
#  'vilhena',
#  'pisco',
#  'barcelos',
#  'tanout',
#  'tshabong',
#  'merizo village',
#  'kerikeri',
#  'fada',
#  'cestos city',
#  'idri',
#  'vernon',
#  'el hadjira',
#  'ramadi',
#  'vorgashor',
#  'safotu',
#  'korsakov',
#  'aral',
#  'gusev',
#  'punta arenas',
#  'burutu',
#  'lethem',
#  'aleksandrovsk-sakhalinskiy',
#  'dawson creek',
#  'miandrivazo',
#  'cole harbour',
#  'linqiong',
#  'puerto madero',
#  'adam',
#  'kale',
#  'jaffa',
#  'nova sintra',
#  'acarau',
#  'santa terezinha',
#  'gerash',
#  'eenhana',
#  'atafu village',
#  'shenjiamen',
#  'chernyshevskiy',
#  'bodo',
#  'kattivakkam',
#  'pitimbu',
#  'malango',
#  'verkhnevilyuysk',
#  'alice springs',
#  'desarmes',
#  'fisterra',
#  'kotlas',
#  'arteche',
#  'nemuro',
#  'paracuru',
#  'cannonvale',
#  'galesong',
#  'maun',
#  'imperatriz',
#  'nizhnesortymskiy',
#  'chibougamau',
#  'uruzgan',
#  'charters towers',
#  'la passe',
#  'crikvenica',
#  'timaru',
#  'tarana',
#  'peterhead',
#  'colby',
#  'moratuwa',
#  'misratah',
#  'manokwari',
#  'baki',
#  'puerto san carlos',
#  'fuvahmulah',
#  'port augusta',
#  'punta del este',
#  'namtsy',
#  'rabo de peixe',
#  'carutapera',
#  "la'ie",
#  'petropavlovsk-kamchatsky',
#  'copala',
#  'mananjary',
#  'barra de santo antonio',
#  'beberibe',
#  'remire-montjoly',
#  'maba',
#  'altinekin',
#  'grantsville',
#  'nelson bay',
#  'raahe',
#  'bereznik',
#  'arhribs',
#  'cangzhou',
#  'castro',
#  'nechi',
#  'holualoa',
#  'carnarvon',
#  'viedma',
#  'harriman',
#  'santa elena de uairen',
#  'ponta delgada',
#  'yen bai',
#  'mugia',
#  'khandyga',
#  'myrina',
#  'yamada',
#  'pandan',
#  'galeras',
#  'mahebourg',
#  'itoman',
#  'alvarado',
#  'yangor',
#  'baidoa',
#  'sinabang',
#  'san fernando de apure',
#  'shalya',
#  'dhidhdhoo',
#  'mushie',
#  'kataragama',
#  'mirpur sakro',
#  'xilin hot',
#  'akom ii',
#  'taoudenni',
#  'port douglas',
#  'island harbour',
#  'kondratovo',
#  'guatire',
#  'sao benedito do rio preto',
#  'sidi bel abbes',
#  'dellys',
#  "jian'ou",
#  'bowen',
#  'tadine',
#  'i-n-salah',
#  'tsiombe',
#  'namsos',
#  'taulaga',
#  'nuea khlong',
#  'gebeit',
#  'itamaraca',
#  'salalah',
#  'buala',
#  'sihanoukville',
#  'luwero',
#  'damara',
#  'guatrache',
#  'kursenai',
#  'cockburn town',
#  'ifakara',
#  'cabedelo',
#  'shahdad kot',
#  'bull savanna',
#  'westport',
#  'as sulayyil',
#  'borogontsy',
#  'bonthe',
#  'chongwe',
#  'moose jaw',
#  'csenger',
#  'williams lake',
#  'srinagar',
#  'atar',
#  'brookings',
#  'urangan',
#  'espargos',
#  'festus',
#  'sinop',
#  'sao vicente',
#  'jackson',
#  'crane',
#  'piacabucu',
#  'ilhabela',
#  'san luis',
#  'vanimo',
#  'tenno',
#  'safi',
#  'longboat key',
#  'divnogorsk',
#  'kizel',
#  'erenhot',
#  "port saint john's",
#  'kapit',
#  'lerwick',
#  'mahibadhoo',
#  'howrah',
#  'papao',
#  'la libertad',
#  'kone',
#  'boonville',
#  'bismarck',
#  'saint-pierre',
#  'kepno',
#  'saint-mandrier-sur-mer',
#  'basco',
#  'nouadhibou',
#  'jiazi',
#  'chabahar',
#  "abraham's bay",
#  'yuzhno-kurilsk',
#  'ribeira brava',
#  'xuddur',
#  'korla',
#  'belyy yar',
#  'lembar',
#  'radviliskis',
#  "fu'an",
#  'laguna',
#  'ad darb',
#  'sisimiut',
#  'dakhla',
#  'es castell',
#  'rurrenabaque',
#  'hotan',
#  'najran',
#  'lihue',
#  'ternate',
#  'knysna',
#  'axim',
#  'newman',
#  'pestovo',
#  'mocajuba',
#  'el bauga',
#  "kapa'a",
#  'canete',
#  'callao',
#  'port-vila',
#  'new river',
#  'saudarkrokur',
#  'sinjai',
#  'magadan',
#  'seven pagodas',
#  'tvoroyri',
#  'zaozersk',
#  'castel di sangro',
#  'cabo san lucas',
#  'ulsteinvik',
#  'nkove',
#  'arish',
#  'krupki',
#  'yeppoon',
#  'arti',
#  'kez',
#  'khenifra',
#  'winkler',
#  'al-hamdaniya',
#  'colipapa',
#  'altagracia de orituco',
#  'freetown',
#  'mizdah',
#  'kolonia town',
#  'mwinilunga',
#  'acapulco de juarez',
#  'quepos',
#  'keflavik',
#  'tataouine',
#  'alofi',
#  'kayangel',
#  'san luis de la loma',
#  'bebedja',
#  'kovernino',
#  'krasnobrodskiy',
#  'wongsorejo',
#  'happy valley-goose bay',
#  'hangu',
#  'fredericton',
#  'el granada',
#  'sitka',
#  'loralai',
#  'lashio',
#  'kayyerkan',
#  'mossel bay',
#  'chengdu',
#  'katsuura',
#  'vuktyl',
#  'isangel',
#  'qingdao',
#  'vila velha',
#  'bamyan',
#  'kolondieba',
#  'hoxtolgay',
#  'funafuti',
#  'petrila',
#  'san ignacio',
#  'tofol',
#  'franceville',
#  'gao',
#  'montfort-sur-meu',
#  'cidreira',
#  'kasongo',
#  "sovetskaya gavan'",
#  'chadan',
#  'naze',
#  'pointe-noire',
#  'kaedi',
#  'bryan',
#  'bhinga',
#  'santana',
#  'cill airne',
#  'nadvoitsy',
#  'we',
#  'mount isa',
#  'howard springs',
#  'torghay',
#  'al jawf',
#  'mahanje',
#  'al bawiti',
#  'maringa',
#  'puerto princesa',
#  'zangguy',
#  "mil'kovo",
#  "kargopol'",
#  'teguise',
#  'conceicao do araguaia',
#  'fiambala',
#  'valdivia',
#  'pudozh']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
city_url = f"{url}&q={city}"
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=metric&appid=52da5fabd98a3339521bed038b642295&q=pudozh'

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | whitehorse
# Processing Record 2 of Set 1 | puerto natales
# Processing Record 3 of Set 1 | olonkinbyen
# Processing Record 4 of Set 1 | oromocto
# Processing Record 5 of Set 1 | enewetak
# Processing Record 6 of Set 1 | fort mcmurray
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | adamstown
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | sur
# Processing Record 11 of Set 1 | muricay
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | mount gambier
# Processing Record 14 of Set 1 | zapolyarnyy
# Processing Record 15 of Set 1 | cobija
# Processing Record 16 of Set 1 | edinburgh of the seven seas
# Processing Record 17 of Set 1 | santa marta
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | saint-francois
# Processing Record 21 of Set 1 | dunedin
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | kingston
# Processing Record 24 of Set 1 | belmonte
# Processing Record 25 of Set 1 | abrud
# Processing Record 26 of Set 1 | kaihua
# Processing Record 27 of Set 1 | karangampel
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | puerto baquerizo moreno
# Processing Record 30 of Set 1 | gonabad
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | alesund
# Processing Record 33 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 34 of Set 1 | juneau
# Processing Record 35 of Set 1 | palikir - national government center
# Processing Record 36 of Set 1 | nybro
# Processing Record 37 of Set 1 | nabire
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | sept-iles
# Processing Record 40 of Set 1 | turpan
# Processing Record 41 of Set 1 | warrnambool
# Processing Record 42 of Set 1 | poronaysk
# Processing Record 43 of Set 1 | mount pearl
# Processing Record 44 of Set 1 | badger
# Processing Record 45 of Set 1 | iskateley
# Processing Record 46 of Set 1 | utrik
# Processing Record 47 of Set 1 | port mathurin
# Processing Record 48 of Set 1 | hamilton
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | qaqortoq
# Processing Record 0 of Set 2 | ubinskoye
# Processing Record 1 of Set 2 | port-aux-francais
# Processing Record 2 of Set 2 | west island
# Processing Record 3 of Set 2 | codrington
# Processing Record 4 of Set 2 | college
# Processing Record 5 of Set 2 | port lincoln
# Processing Record 6 of Set 2 | agogo
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | wailua homesteads
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | aykhal
# Processing Record 11 of Set 2 | kapuskasing
# Processing Record 12 of Set 2 | ciudad melchor muzquiz
# Processing Record 13 of Set 2 | blackmans bay
# Processing Record 14 of Set 2 | helena valley southeast
# Processing Record 15 of Set 2 | fortuna
# Processing Record 16 of Set 2 | medina
# Processing Record 17 of Set 2 | ola
# Processing Record 18 of Set 2 | gaspe
# Processing Record 19 of Set 2 | udachny
# Processing Record 20 of Set 2 | patong
# Processing Record 21 of Set 2 | stanley
# Processing Record 22 of Set 2 | papatowai
# Processing Record 23 of Set 2 | talnakh
# Processing Record 24 of Set 2 | okha
# Processing Record 25 of Set 2 | rio grande
# Processing Record 26 of Set 2 | sorong
# Processing Record 27 of Set 2 | nyurba
# Processing Record 28 of Set 2 | antsiranana
# Processing Record 29 of Set 2 | santo antonio
# Processing Record 30 of Set 2 | weno
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | orsa
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | iqaluit
# Processing Record 35 of Set 2 | pacific grove
# Processing Record 36 of Set 2 | torre de moncorvo
# Processing Record 37 of Set 2 | amal
# Processing Record 38 of Set 2 | anna regina
# Processing Record 39 of Set 2 | brisas de zicatela
# Processing Record 40 of Set 2 | port glaud
# City not found. Skipping...
# Processing Record 41 of Set 2 | muisne
# Processing Record 42 of Set 2 | khorugh
# Processing Record 43 of Set 2 | nandurbar
# Processing Record 44 of Set 2 | hadibu
# Processing Record 45 of Set 2 | kavaratti
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | kailua-kona
# Processing Record 48 of Set 2 | carahue
# Processing Record 49 of Set 2 | dudinka
# Processing Record 0 of Set 3 | christchurch
# Processing Record 1 of Set 3 | hasaki
# Processing Record 2 of Set 3 | ugoofaaru
# Processing Record 3 of Set 3 | klyuchi
# Processing Record 4 of Set 3 | margaret river
# Processing Record 5 of Set 3 | saipan
# Processing Record 6 of Set 3 | recani
# Processing Record 7 of Set 3 | mukah
# City not found. Skipping...
# Processing Record 8 of Set 3 | katabu
# Processing Record 9 of Set 3 | saint-georges
# Processing Record 10 of Set 3 | polyarnyy
# Processing Record 11 of Set 3 | sao felix do xingu
# Processing Record 12 of Set 3 | nar'yan-mar
# Processing Record 13 of Set 3 | uturoa
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | fale old settlement
# Processing Record 16 of Set 3 | cuatro cienegas de carranza
# Processing Record 17 of Set 3 | jaisinghnagar
# Processing Record 18 of Set 3 | afaahiti
# Processing Record 19 of Set 3 | ikom
# Processing Record 20 of Set 3 | nishinoomote
# Processing Record 21 of Set 3 | san carlos de bariloche
# Processing Record 22 of Set 3 | meadow lake
# Processing Record 23 of Set 3 | den burg
# Processing Record 24 of Set 3 | mogadishu
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | kudymkar
# Processing Record 27 of Set 3 | aoulef
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | ust-nera
# Processing Record 30 of Set 3 | akureyri
# Processing Record 31 of Set 3 | hawaiian paradise park
# Processing Record 32 of Set 3 | richlands
# Processing Record 33 of Set 3 | greenville
# Processing Record 34 of Set 3 | tadpatri
# Processing Record 35 of Set 3 | baiyin
# Processing Record 36 of Set 3 | invercargill
# Processing Record 37 of Set 3 | quelimane
# Processing Record 38 of Set 3 | wrzesnia
# Processing Record 39 of Set 3 | vila franca do campo
# Processing Record 40 of Set 3 | mermoz boabab
# Processing Record 41 of Set 3 | chonchi
# Processing Record 42 of Set 3 | ilulissat
# Processing Record 43 of Set 3 | port elizabeth
# Processing Record 44 of Set 3 | tonota
# Processing Record 45 of Set 3 | xai-xai
# Processing Record 46 of Set 3 | hobyo
# Processing Record 47 of Set 3 | abepura
# Processing Record 48 of Set 3 | wellington
# Processing Record 49 of Set 3 | bardai
# Processing Record 0 of Set 4 | hanceville
# Processing Record 1 of Set 4 | vadso
# Processing Record 2 of Set 4 | ancud
# Processing Record 3 of Set 4 | hilo
# Processing Record 4 of Set 4 | kalodzishchy
# Processing Record 5 of Set 4 | vilyuchinsk
# Processing Record 6 of Set 4 | rapid city
# Processing Record 7 of Set 4 | feijo
# Processing Record 8 of Set 4 | touros
# Processing Record 9 of Set 4 | tazovsky
# Processing Record 10 of Set 4 | katsuren-haebaru
# Processing Record 11 of Set 4 | lebu
# Processing Record 12 of Set 4 | vorkuta
# Processing Record 13 of Set 4 | krasnogorskoye
# Processing Record 14 of Set 4 | tura
# Processing Record 15 of Set 4 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 16 of Set 4 | susuman
# Processing Record 17 of Set 4 | georgetown
# Processing Record 18 of Set 4 | flin flon
# Processing Record 19 of Set 4 | rabaul
# Processing Record 20 of Set 4 | paphos
# Processing Record 21 of Set 4 | buka
# Processing Record 22 of Set 4 | queenstown
# Processing Record 23 of Set 4 | kovdor
# Processing Record 24 of Set 4 | brak
# Processing Record 25 of Set 4 | izucar de matamoros
# Processing Record 26 of Set 4 | thal
# Processing Record 27 of Set 4 | port alfred
# Processing Record 28 of Set 4 | kutztown
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | valparaiso
# Processing Record 31 of Set 4 | minbu
# Processing Record 32 of Set 4 | bikenibeu village
# Processing Record 33 of Set 4 | zaigrayevo
# Processing Record 34 of Set 4 | aasiaat
# Processing Record 35 of Set 4 | beledweyne
# Processing Record 36 of Set 4 | neijiang
# Processing Record 37 of Set 4 | sangkhla buri
# Processing Record 38 of Set 4 | anadyr
# Processing Record 39 of Set 4 | pelabuhan klang
# Processing Record 40 of Set 4 | ndago
# Processing Record 41 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 42 of Set 4 | karratha
# Processing Record 43 of Set 4 | haiku-pauwela
# Processing Record 44 of Set 4 | coquimbo
# Processing Record 45 of Set 4 | castillos
# Processing Record 46 of Set 4 | tanumah
# Processing Record 47 of Set 4 | prince george
# Processing Record 48 of Set 4 | sumbawa besar
# Processing Record 49 of Set 4 | waddan
# Processing Record 0 of Set 5 | tolanaro
# Processing Record 1 of Set 5 | la palma
# Processing Record 2 of Set 5 | urucara
# Processing Record 3 of Set 5 | manatutu
# City not found. Skipping...
# Processing Record 4 of Set 5 | great falls
# Processing Record 5 of Set 5 | ouesso
# Processing Record 6 of Set 5 | kalix
# Processing Record 7 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 8 of Set 5 | nurota
# Processing Record 9 of Set 5 | honcho
# Processing Record 10 of Set 5 | duyun
# Processing Record 11 of Set 5 | upata
# Processing Record 12 of Set 5 | okhotsk
# Processing Record 13 of Set 5 | tamanrasset
# Processing Record 14 of Set 5 | kotli loharan
# Processing Record 15 of Set 5 | weligama
# Processing Record 16 of Set 5 | balikpapan
# Processing Record 17 of Set 5 | midvagur
# Processing Record 18 of Set 5 | kidal
# Processing Record 19 of Set 5 | asadabad
# Processing Record 20 of Set 5 | new norfolk
# Processing Record 21 of Set 5 | camiri
# Processing Record 22 of Set 5 | gap
# Processing Record 23 of Set 5 | labytnangi
# Processing Record 24 of Set 5 | egilsstadir
# Processing Record 25 of Set 5 | islamkot
# Processing Record 26 of Set 5 | slave lake
# Processing Record 27 of Set 5 | east london
# Processing Record 28 of Set 5 | paide
# Processing Record 29 of Set 5 | muniz freire
# Processing Record 30 of Set 5 | kangding
# Processing Record 31 of Set 5 | orikhiv
# Processing Record 32 of Set 5 | qamdo
# Processing Record 33 of Set 5 | galle
# Processing Record 34 of Set 5 | nizao
# Processing Record 35 of Set 5 | omuthiya
# City not found. Skipping...
# Processing Record 36 of Set 5 | san patricio
# Processing Record 37 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 38 of Set 5 | lorengau
# Processing Record 39 of Set 5 | nuku'alofa
# Processing Record 40 of Set 5 | mbanza kongo
# Processing Record 41 of Set 5 | kalmunai
# Processing Record 42 of Set 5 | tebingtinggi
# Processing Record 43 of Set 5 | santa isabel
# Processing Record 44 of Set 5 | corovode
# Processing Record 45 of Set 5 | finspang
# Processing Record 46 of Set 5 | shani
# Processing Record 47 of Set 5 | ca mau
# Processing Record 48 of Set 5 | isafjordur
# Processing Record 49 of Set 5 | kristiansund
# Processing Record 0 of Set 6 | andergrove
# Processing Record 1 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 2 of Set 6 | st. john's
# Processing Record 3 of Set 6 | porto novo
# Processing Record 4 of Set 6 | yelovo
# Processing Record 5 of Set 6 | kargasok
# Processing Record 6 of Set 6 | bilibino
# Processing Record 7 of Set 6 | bargara
# City not found. Skipping...
# Processing Record 8 of Set 6 | mersa matruh
# Processing Record 9 of Set 6 | cromwell
# Processing Record 10 of Set 6 | kaa-khem
# Processing Record 11 of Set 6 | tessaoua
# Processing Record 12 of Set 6 | shimoda
# Processing Record 13 of Set 6 | qandala
# Processing Record 14 of Set 6 | rheinsberg
# Processing Record 15 of Set 6 | sosnogorsk
# Processing Record 16 of Set 6 | tommot
# Processing Record 17 of Set 6 | broken hill
# Processing Record 18 of Set 6 | labrador city
# Processing Record 19 of Set 6 | quellon
# Processing Record 20 of Set 6 | kadisehri
# Processing Record 21 of Set 6 | lompoc
# Processing Record 22 of Set 6 | yarmouth
# Processing Record 23 of Set 6 | dalandzadgad
# Processing Record 24 of Set 6 | agapovka
# Processing Record 25 of Set 6 | flying fish cove
# Processing Record 26 of Set 6 | poli
# Processing Record 27 of Set 6 | esbjerg
# Processing Record 28 of Set 6 | constantia
# Processing Record 29 of Set 6 | le krib
# Processing Record 30 of Set 6 | negara
# Processing Record 31 of Set 6 | 'ain benian
# Processing Record 32 of Set 6 | nuuk
# Processing Record 33 of Set 6 | terenozek
# Processing Record 34 of Set 6 | kuqa
# Processing Record 35 of Set 6 | vilhena
# Processing Record 36 of Set 6 | pisco
# Processing Record 37 of Set 6 | barcelos
# Processing Record 38 of Set 6 | tanout
# Processing Record 39 of Set 6 | tshabong
# Processing Record 40 of Set 6 | merizo village
# Processing Record 41 of Set 6 | kerikeri
# Processing Record 42 of Set 6 | fada
# Processing Record 43 of Set 6 | cestos city
# Processing Record 44 of Set 6 | idri
# Processing Record 45 of Set 6 | vernon
# Processing Record 46 of Set 6 | el hadjira
# Processing Record 47 of Set 6 | ramadi
# Processing Record 48 of Set 6 | vorgashor
# Processing Record 49 of Set 6 | safotu
# Processing Record 0 of Set 7 | korsakov
# Processing Record 1 of Set 7 | aral
# Processing Record 2 of Set 7 | gusev
# Processing Record 3 of Set 7 | punta arenas
# Processing Record 4 of Set 7 | burutu
# Processing Record 5 of Set 7 | lethem
# Processing Record 6 of Set 7 | aleksandrovsk-sakhalinskiy
# Processing Record 7 of Set 7 | dawson creek
# Processing Record 8 of Set 7 | miandrivazo
# Processing Record 9 of Set 7 | cole harbour
# Processing Record 10 of Set 7 | linqiong
# Processing Record 11 of Set 7 | puerto madero
# Processing Record 12 of Set 7 | adam
# Processing Record 13 of Set 7 | kale
# Processing Record 14 of Set 7 | jaffa
# Processing Record 15 of Set 7 | nova sintra
# Processing Record 16 of Set 7 | acarau
# Processing Record 17 of Set 7 | santa terezinha
# Processing Record 18 of Set 7 | gerash
# Processing Record 19 of Set 7 | eenhana
# Processing Record 20 of Set 7 | atafu village
# Processing Record 21 of Set 7 | shenjiamen
# Processing Record 22 of Set 7 | chernyshevskiy
# Processing Record 23 of Set 7 | bodo
# Processing Record 24 of Set 7 | kattivakkam
# Processing Record 25 of Set 7 | pitimbu
# Processing Record 26 of Set 7 | malango
# Processing Record 27 of Set 7 | verkhnevilyuysk
# Processing Record 28 of Set 7 | alice springs
# Processing Record 29 of Set 7 | desarmes
# Processing Record 30 of Set 7 | fisterra
# Processing Record 31 of Set 7 | kotlas
# Processing Record 32 of Set 7 | arteche
# Processing Record 33 of Set 7 | nemuro
# Processing Record 34 of Set 7 | paracuru
# Processing Record 35 of Set 7 | cannonvale
# Processing Record 36 of Set 7 | galesong
# Processing Record 37 of Set 7 | maun
# Processing Record 38 of Set 7 | imperatriz
# Processing Record 39 of Set 7 | nizhnesortymskiy
# Processing Record 40 of Set 7 | chibougamau
# Processing Record 41 of Set 7 | uruzgan
# Processing Record 42 of Set 7 | charters towers
# Processing Record 43 of Set 7 | la passe
# Processing Record 44 of Set 7 | crikvenica
# Processing Record 45 of Set 7 | timaru
# Processing Record 46 of Set 7 | tarana
# Processing Record 47 of Set 7 | peterhead
# Processing Record 48 of Set 7 | colby
# Processing Record 49 of Set 7 | moratuwa
# Processing Record 0 of Set 8 | misratah
# Processing Record 1 of Set 8 | manokwari
# Processing Record 2 of Set 8 | baki
# Processing Record 3 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 5 of Set 8 | port augusta
# Processing Record 6 of Set 8 | punta del este
# Processing Record 7 of Set 8 | namtsy
# Processing Record 8 of Set 8 | rabo de peixe
# Processing Record 9 of Set 8 | carutapera
# Processing Record 10 of Set 8 | la'ie
# Processing Record 11 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 12 of Set 8 | copala
# Processing Record 13 of Set 8 | mananjary
# Processing Record 14 of Set 8 | barra de santo antonio
# Processing Record 15 of Set 8 | beberibe
# Processing Record 16 of Set 8 | remire-montjoly
# Processing Record 17 of Set 8 | maba
# Processing Record 18 of Set 8 | altinekin
# Processing Record 19 of Set 8 | grantsville
# Processing Record 20 of Set 8 | nelson bay
# Processing Record 21 of Set 8 | raahe
# Processing Record 22 of Set 8 | bereznik
# Processing Record 23 of Set 8 | arhribs
# Processing Record 24 of Set 8 | cangzhou
# Processing Record 25 of Set 8 | castro
# Processing Record 26 of Set 8 | nechi
# Processing Record 27 of Set 8 | holualoa
# Processing Record 28 of Set 8 | carnarvon
# Processing Record 29 of Set 8 | viedma
# Processing Record 30 of Set 8 | harriman
# Processing Record 31 of Set 8 | santa elena de uairen
# Processing Record 32 of Set 8 | ponta delgada
# Processing Record 33 of Set 8 | yen bai
# Processing Record 34 of Set 8 | mugia
# Processing Record 35 of Set 8 | khandyga
# Processing Record 36 of Set 8 | myrina
# Processing Record 37 of Set 8 | yamada
# Processing Record 38 of Set 8 | pandan
# Processing Record 39 of Set 8 | galeras
# Processing Record 40 of Set 8 | mahebourg
# Processing Record 41 of Set 8 | itoman
# Processing Record 42 of Set 8 | alvarado
# Processing Record 43 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 44 of Set 8 | baidoa
# Processing Record 45 of Set 8 | sinabang
# Processing Record 46 of Set 8 | san fernando de apure
# Processing Record 47 of Set 8 | shalya
# Processing Record 48 of Set 8 | dhidhdhoo
# Processing Record 49 of Set 8 | mushie
# Processing Record 0 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 1 of Set 9 | mirpur sakro
# Processing Record 2 of Set 9 | xilin hot
# Processing Record 3 of Set 9 | akom ii
# Processing Record 4 of Set 9 | taoudenni
# Processing Record 5 of Set 9 | port douglas
# Processing Record 6 of Set 9 | island harbour
# Processing Record 7 of Set 9 | kondratovo
# Processing Record 8 of Set 9 | guatire
# Processing Record 9 of Set 9 | sao benedito do rio preto
# Processing Record 10 of Set 9 | sidi bel abbes
# Processing Record 11 of Set 9 | dellys
# Processing Record 12 of Set 9 | jian'ou
# Processing Record 13 of Set 9 | bowen
# Processing Record 14 of Set 9 | tadine
# Processing Record 15 of Set 9 | i-n-salah
# Processing Record 16 of Set 9 | tsiombe
# Processing Record 17 of Set 9 | namsos
# Processing Record 18 of Set 9 | taulaga
# Processing Record 19 of Set 9 | nuea khlong
# Processing Record 20 of Set 9 | gebeit
# Processing Record 21 of Set 9 | itamaraca
# Processing Record 22 of Set 9 | salalah
# Processing Record 23 of Set 9 | buala
# Processing Record 24 of Set 9 | sihanoukville
# Processing Record 25 of Set 9 | luwero
# Processing Record 26 of Set 9 | damara
# Processing Record 27 of Set 9 | guatrache
# Processing Record 28 of Set 9 | kursenai
# Processing Record 29 of Set 9 | cockburn town
# Processing Record 30 of Set 9 | ifakara
# Processing Record 31 of Set 9 | cabedelo
# Processing Record 32 of Set 9 | shahdad kot
# Processing Record 33 of Set 9 | bull savanna
# Processing Record 34 of Set 9 | westport
# Processing Record 35 of Set 9 | as sulayyil
# Processing Record 36 of Set 9 | borogontsy
# Processing Record 37 of Set 9 | bonthe
# Processing Record 38 of Set 9 | chongwe
# Processing Record 39 of Set 9 | moose jaw
# Processing Record 40 of Set 9 | csenger
# Processing Record 41 of Set 9 | williams lake
# Processing Record 42 of Set 9 | srinagar
# Processing Record 43 of Set 9 | atar
# Processing Record 44 of Set 9 | brookings
# Processing Record 45 of Set 9 | urangan
# Processing Record 46 of Set 9 | espargos
# City not found. Skipping...
# Processing Record 47 of Set 9 | festus
# Processing Record 48 of Set 9 | sinop
# Processing Record 49 of Set 9 | sao vicente
# Processing Record 0 of Set 10 | jackson
# Processing Record 1 of Set 10 | crane
# Processing Record 2 of Set 10 | piacabucu
# Processing Record 3 of Set 10 | ilhabela
# Processing Record 4 of Set 10 | san luis
# Processing Record 5 of Set 10 | vanimo
# Processing Record 6 of Set 10 | tenno
# Processing Record 7 of Set 10 | safi
# Processing Record 8 of Set 10 | longboat key
# Processing Record 9 of Set 10 | divnogorsk
# Processing Record 10 of Set 10 | kizel
# Processing Record 11 of Set 10 | erenhot
# Processing Record 12 of Set 10 | port saint john's
# Processing Record 13 of Set 10 | kapit
# Processing Record 14 of Set 10 | lerwick
# Processing Record 15 of Set 10 | mahibadhoo
# Processing Record 16 of Set 10 | howrah
# Processing Record 17 of Set 10 | papao
# Processing Record 18 of Set 10 | la libertad
# Processing Record 19 of Set 10 | kone
# Processing Record 20 of Set 10 | boonville
# Processing Record 21 of Set 10 | bismarck
# Processing Record 22 of Set 10 | saint-pierre
# Processing Record 23 of Set 10 | kepno
# Processing Record 24 of Set 10 | saint-mandrier-sur-mer
# Processing Record 25 of Set 10 | basco
# Processing Record 26 of Set 10 | nouadhibou
# Processing Record 27 of Set 10 | jiazi
# Processing Record 28 of Set 10 | chabahar
# Processing Record 29 of Set 10 | abraham's bay
# City not found. Skipping...
# Processing Record 30 of Set 10 | yuzhno-kurilsk
# Processing Record 31 of Set 10 | ribeira brava
# Processing Record 32 of Set 10 | xuddur
# Processing Record 33 of Set 10 | korla
# Processing Record 34 of Set 10 | belyy yar
# Processing Record 35 of Set 10 | lembar
# City not found. Skipping...
# Processing Record 36 of Set 10 | radviliskis
# Processing Record 37 of Set 10 | fu'an
# Processing Record 38 of Set 10 | laguna
# Processing Record 39 of Set 10 | ad darb
# Processing Record 40 of Set 10 | sisimiut
# Processing Record 41 of Set 10 | dakhla
# Processing Record 42 of Set 10 | es castell
# Processing Record 43 of Set 10 | rurrenabaque
# Processing Record 44 of Set 10 | hotan
# Processing Record 45 of Set 10 | najran
# Processing Record 46 of Set 10 | lihue
# Processing Record 47 of Set 10 | ternate
# Processing Record 48 of Set 10 | knysna
# Processing Record 49 of Set 10 | axim
# Processing Record 0 of Set 11 | newman
# Processing Record 1 of Set 11 | pestovo
# Processing Record 2 of Set 11 | mocajuba
# Processing Record 3 of Set 11 | el bauga
# Processing Record 4 of Set 11 | kapa'a
# Processing Record 5 of Set 11 | canete
# Processing Record 6 of Set 11 | callao
# Processing Record 7 of Set 11 | port-vila
# Processing Record 8 of Set 11 | new river
# Processing Record 9 of Set 11 | saudarkrokur
# Processing Record 10 of Set 11 | sinjai
# Processing Record 11 of Set 11 | magadan
# Processing Record 12 of Set 11 | seven pagodas
# Processing Record 13 of Set 11 | tvoroyri
# Processing Record 14 of Set 11 | zaozersk
# Processing Record 15 of Set 11 | castel di sangro
# Processing Record 16 of Set 11 | cabo san lucas
# Processing Record 17 of Set 11 | ulsteinvik
# Processing Record 18 of Set 11 | nkove
# Processing Record 19 of Set 11 | arish
# Processing Record 20 of Set 11 | krupki
# Processing Record 21 of Set 11 | yeppoon
# Processing Record 22 of Set 11 | arti
# Processing Record 23 of Set 11 | kez
# Processing Record 24 of Set 11 | khenifra
# Processing Record 25 of Set 11 | winkler
# Processing Record 26 of Set 11 | al-hamdaniya
# Processing Record 27 of Set 11 | colipapa
# Processing Record 28 of Set 11 | altagracia de orituco
# Processing Record 29 of Set 11 | freetown
# Processing Record 30 of Set 11 | mizdah
# Processing Record 31 of Set 11 | kolonia town
# Processing Record 32 of Set 11 | mwinilunga
# Processing Record 33 of Set 11 | acapulco de juarez
# Processing Record 34 of Set 11 | quepos
# Processing Record 35 of Set 11 | keflavik
# Processing Record 36 of Set 11 | tataouine
# Processing Record 37 of Set 11 | alofi
# Processing Record 38 of Set 11 | kayangel
# Processing Record 39 of Set 11 | san luis de la loma
# Processing Record 40 of Set 11 | bebedja
# Processing Record 41 of Set 11 | kovernino
# Processing Record 42 of Set 11 | krasnobrodskiy
# Processing Record 43 of Set 11 | wongsorejo
# Processing Record 44 of Set 11 | happy valley-goose bay
# Processing Record 45 of Set 11 | hangu
# Processing Record 46 of Set 11 | fredericton
# Processing Record 47 of Set 11 | el granada
# Processing Record 48 of Set 11 | sitka
# Processing Record 49 of Set 11 | loralai
# Processing Record 0 of Set 12 | lashio
# Processing Record 1 of Set 12 | kayyerkan
# Processing Record 2 of Set 12 | mossel bay
# Processing Record 3 of Set 12 | chengdu
# Processing Record 4 of Set 12 | katsuura
# Processing Record 5 of Set 12 | vuktyl
# Processing Record 6 of Set 12 | isangel
# Processing Record 7 of Set 12 | qingdao
# Processing Record 8 of Set 12 | vila velha
# Processing Record 9 of Set 12 | bamyan
# Processing Record 10 of Set 12 | kolondieba
# Processing Record 11 of Set 12 | hoxtolgay
# City not found. Skipping...
# Processing Record 12 of Set 12 | funafuti
# Processing Record 13 of Set 12 | petrila
# Processing Record 14 of Set 12 | san ignacio
# Processing Record 15 of Set 12 | tofol
# Processing Record 16 of Set 12 | franceville
# Processing Record 17 of Set 12 | gao
# Processing Record 18 of Set 12 | montfort-sur-meu
# Processing Record 19 of Set 12 | cidreira
# Processing Record 20 of Set 12 | kasongo
# Processing Record 21 of Set 12 | sovetskaya gavan'
# Processing Record 22 of Set 12 | chadan
# Processing Record 23 of Set 12 | naze
# Processing Record 24 of Set 12 | pointe-noire
# Processing Record 25 of Set 12 | kaedi
# Processing Record 26 of Set 12 | bryan
# Processing Record 27 of Set 12 | bhinga
# Processing Record 28 of Set 12 | santana
# Processing Record 29 of Set 12 | cill airne
# Processing Record 30 of Set 12 | nadvoitsy
# Processing Record 31 of Set 12 | we
# City not found. Skipping...
# Processing Record 32 of Set 12 | mount isa
# Processing Record 33 of Set 12 | howard springs
# Processing Record 34 of Set 12 | torghay
# Processing Record 35 of Set 12 | al jawf
# Processing Record 36 of Set 12 | mahanje
# Processing Record 37 of Set 12 | al bawiti
# Processing Record 38 of Set 12 | maringa
# Processing Record 39 of Set 12 | puerto princesa
# Processing Record 40 of Set 12 | zangguy
# City not found. Skipping...
# Processing Record 41 of Set 12 | mil'kovo
# Processing Record 42 of Set 12 | kargopol'
# Processing Record 43 of Set 12 | teguise
# Processing Record 44 of Set 12 | conceicao do araguaia
# Processing Record 45 of Set 12 | fiambala
# Processing Record 46 of Set 12 | valdivia
# Processing Record 47 of Set 12 | pudozh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      whitehorse  60.7161 -135.0538     -9.57        92          40
# 1  puerto natales -51.7236  -72.4875     14.25        47          75
# 2     olonkinbyen  70.9221   -8.7187     -3.64        88         100
# 3        oromocto  45.8351  -66.4792     -3.04        63           0
# 4        enewetak  11.3474  162.3373     27.82        79          23
#
#    Wind Speed Country        Date
# 0        5.66      CA  1733770025
# 1        6.69      CL  1733770026
# 2        7.18      SJ  1733770027
# 3        2.57      CA  1733770028
# 4        8.17      MH  1733770029

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            whitehorse  60.7161 -135.0538     -9.57        92          40
# 1        puerto natales -51.7236  -72.4875     14.25        47          75
# 2           olonkinbyen  70.9221   -8.7187     -3.64        88         100
# 3              oromocto  45.8351  -66.4792     -3.04        63           0
# 4              enewetak  11.3474  162.3373     27.82        79          23
#
#          Wind Speed Country        Date
# City_ID
# 0              5.66      CA  1733770025
# 1              6.69      CL  1733770026
# 2              7.18      SJ  1733770027
# 3              2.57      CA  1733770028
# 4              8.17      MH  1733770029

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor = "red",
    linewidths = 1,
    marker = "o",
    alpha = 0.8,
    label = "Cities"
)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title(f" City Max Latitude vs. Temperature (%s) ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
# Save the figure

plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor = "black",
    linewidths = 1,
    marker = "o",
    alpha = 0.8,
    label = "Cities"
)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title(f" City Max Latitude vs. Humidity (%s) ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor = "purple",
    linewidths = 1,
    marker = "o",
    alpha = 0.8,
    label = "Cities"
)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title(f" City Max Latitude vs. Cloudiness ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor = "red",
    linewidths = 1,
    marker = "o",
    alpha = 0.8,
    label = "Cities"
)
# Incorporate the other graph properties
# YOUR CODE HERE
plt.title(f" City Max Latitude vs. Wind Speed ({time.strftime('%Y-%m-%d')})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def plot_linear_regression(x_value, y_value, title, text_coord):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope, 2)}x +{round (intercept, 2)}"

    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize = 15, color = "red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue * 2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df[city_data_df["Lat"] >=0]
# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           whitehorse  60.7161 -135.0538     -9.57        92          40
# 2          olonkinbyen  70.9221   -8.7187     -3.64        88         100
# 3             oromocto  45.8351  -66.4792     -3.04        63           0
# 4             enewetak  11.3474  162.3373     27.82        79          23
# 5        fort mcmurray  56.7268 -111.3810     -5.23        93         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.66      CA  1733770025
# 2              7.18      SJ  1733770027
# 3              2.57      CA  1733770028
# 4              8.17      MH  1733770029
# 5              2.57      CA  1733770031

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        puerto natales -51.7236  -72.4875     14.25        47          75
# 6             grytviken -54.2811  -36.5092      2.79        67          26
# 7             adamstown -25.0660 -130.1015     22.77        75          25
# 12        mount gambier -37.8333  140.7667     11.17        77          92
# 14               cobija -11.0267  -68.7692     30.10        70          75
#
#          Wind Speed Country        Date
# City_ID
# 1              6.69      CL  1733770026
# 6              4.22      GS  1733770032
# 7              7.91      PN  1733770033
# 12             1.66      AU  1733770038
# 14             5.14      BO  1733770041

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (6, -10))
# Out:
# The r-value is -1.6985810321895176

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55, 5))
# Out:
# The r-value is 1.4404489372499107

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (50, 20))
# Out:
# The r-value is 0.8180391033262242

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (50, 20))
# Out:
# The r-value is 0.5221386023736524

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (40, 20))
# Out:
# The r-value is 0.4484040699332009

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-50, 25))
# Out:
# The r-value is 0.33954445906942327

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10, 15))
# Out:
# The r-value is 0.47680442119635097

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50, 10))
# Out:
# The r-value is -0.38403788173185477

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
